# %%
from langchain_text_splitters import RecursiveJsonSplitter
import json
import requests

json_data = requests.get("https://api.smith.langchain.com/openapi.json").json()


json_splitter = RecursiveJsonSplitter(max_chunk_size=100)

splitted_json = json_splitter.split_json(json_data)
splitted_json
# Out:
# [{'openapi': '3.1.0', 'info': {'title': 'LangSmith', 'version': '0.1.0'}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'summary': 'Get Tracing Project Prebuilt Dashboard'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'description': 'Get a prebuilt dashboard for a tracing project.'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'operationId': 'get_tracing_project_prebuilt_dashboard_api_v1_sessions__session_id__dashboard_post'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'parameters': [{'name': 'session_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Session Id'}},
#       {'name': 'accept',
#        'in': 'header',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'title': 'Accept'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/CustomChartsSectionRequest'}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/CustomChartsSection'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'summary': 'Read Tracer Session'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'description': 'Get a specific session.'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'operationId': 'read_tracer_session_api_v1_sessions__session_id__get'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'parameters': [{'name': 'session_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Session Id'}},
#       {'name': 'include_stats',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'boolean',
#         'default': False,
#         'title': 'Include Stats'}},
#       {'name': 'accept',
#        'in': 'header',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'title': 'Accept'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/TracerSession'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'summary': 'Update Tracer Session'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'description': 'Create a new session.'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'operationId': 'update_tracer_session_api_v1_sessions__session_id__patch'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'parameters': [{'name': 'session_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'uuid',
#         'title': 'Session Id'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/TracerSessionUpdate'}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/TracerSessionWithoutVirtualFields'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'summary': 'Delete Tracer Session'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'description': 'Delete a specific session.'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'operationId': 'delete_tracer_session_api_v1_sessions__session_id__delete'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'parameters': [{'name': 'session_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'uuid',
#         'title': 'Session Id'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'responses': {'200': {'description': 'Successful Response',
#        'content': {'application/json': {'schema': {}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'summary': 'Read Tracer Sessions'}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'description': 'Get all sessions.'}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'operationId': 'read_tracer_sessions_api_v1_sessions_get'}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'parameters': [{'name': 'reference_free',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'boolean'}, {'type': 'null'}],
#         'title': 'Reference Free'}},
#       {'name': 'reference_dataset',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'array',
#           'items': {'type': 'string', 'format': 'uuid'}},
#          {'type': 'null'}],
#         'title': 'Reference Dataset'}},
#       {'name': 'id',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'array',
#           'items': {'type': 'string', 'format': 'uuid'}},
#          {'type': 'null'}],
#         'title': 'Id'}},
#       {'name': 'name',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'title': 'Name'}},
#       {'name': 'name_contains',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'title': 'Name Contains'}},
#       {'name': 'dataset_version',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'title': 'Dataset Version'}},
#       {'name': 'sort_by',
#        'in': 'query',
#        'required': False,
#        'schema': {'$ref': '#/components/schemas/SessionSortableColumns',
#         'default': 'start_time'}},
#       {'name': 'sort_by_desc',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'boolean',
#         'default': True,
#         'title': 'Sort By Desc'}},
#       {'name': 'metadata',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'title': 'Metadata'}},
#       {'name': 'sort_by_feedback_key',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'title': 'Sort By Feedback Key'}},
#       {'name': 'offset',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'integer',
#         'minimum': 0,
#         'default': 0,
#         'title': 'Offset'}},
#       {'name': 'limit',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'integer',
#         'maximum': 100,
#         'minimum': 1,
#         'default': 100,
#         'title': 'Limit'}},
#       {'name': 'tag_value_id',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'array',
#           'items': {'type': 'string', 'format': 'uuid'}},
#          {'type': 'null'}],
#         'title': 'Tag Value Id'}},
#       {'name': 'facets',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'boolean', 'default': False, 'title': 'Facets'}},
#       {'name': 'filter',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'title': 'Filter'}},
#       {'name': 'include_stats',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'boolean',
#         'default': False,
#         'title': 'Include Stats'}},
#       {'name': 'use_approx_stats',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'boolean',
#         'default': False,
#         'title': 'Use Approx Stats'}},
#       {'name': 'accept',
#        'in': 'header',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'title': 'Accept'}}]}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'type': 'array'}}}}}}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'items': {'$ref': '#/components/schemas/TracerSession'}}}}}}}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'title': 'Response Read Tracer Sessions Api V1 Sessions Get'}}}}}}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'summary': 'Create Tracer Session'}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'description': 'Create a new session.'}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'operationId': 'create_tracer_session_api_v1_sessions_post'}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'parameters': [{'name': 'upsert',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'boolean',
#         'default': False,
#         'title': 'Upsert'}}]}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/TracerSessionCreate'}}}}}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/TracerSessionWithoutVirtualFields'}}}}}}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions': {'delete': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions': {'delete': {'summary': 'Delete Tracer Sessions'}}}},
#  {'paths': {'/api/v1/sessions': {'delete': {'description': 'Delete a specific session.'}}}},
#  {'paths': {'/api/v1/sessions': {'delete': {'operationId': 'delete_tracer_sessions_api_v1_sessions_delete'}}}},
#  {'paths': {'/api/v1/sessions': {'delete': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions': {'delete': {'parameters': [{'name': 'session_ids',
#        'in': 'query',
#        'required': True,
#        'schema': {'type': 'array',
#         'items': {'type': 'string', 'format': 'uuid'},
#         'title': 'Session Ids'}}]}}}},
#  {'paths': {'/api/v1/sessions': {'delete': {'responses': {'200': {'description': 'Successful Response',
#        'content': {'application/json': {'schema': {}}}}}}}}},
#  {'paths': {'/api/v1/sessions': {'delete': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions': {'delete': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'summary': 'Read Tracer Sessions Runs Metadata'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'description': 'Given a session, a number K, and (optionally) a list of metadata keys, return the top K values for each key.'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'operationId': 'read_tracer_sessions_runs_metadata_api_v1_sessions__session_id__metadata_get'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'parameters': [{'name': 'session_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Session Id'}},
#       {'name': 'metadata_keys',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'array', 'items': {'type': 'string'}},
#          {'type': 'null'}],
#         'title': 'Metadata Keys'}},
#       {'name': 'start_time',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string', 'format': 'date-time'},
#          {'type': 'null'}],
#         'title': 'Start Time'}},
#       {'name': 'k',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'integer',
#         'minimum': 1,
#         'default': 10,
#         'title': 'K'}},
#       {'name': 'root_runs_only',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'boolean',
#         'default': False,
#         'title': 'Root Runs Only'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/RootModel_Dict_str__list_str___'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'summary': 'Read Filter Views'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'description': 'Get all filter views for a session.'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'operationId': 'read_filter_views_api_v1_sessions__session_id__views_get'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'parameters': [{'name': 'session_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Session Id'}},
#       {'name': 'type',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'$ref': '#/components/schemas/FilterViewType'},
#          {'type': 'null'}],
#         'title': 'Type'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'type': 'array'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'items': {'$ref': '#/components/schemas/FilterView'}}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'title': 'Response Read Filter Views Api V1 Sessions  Session Id  Views Get'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'summary': 'Create Filter View'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'description': 'Create a new filter view.'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'operationId': 'create_filter_view_api_v1_sessions__session_id__views_post'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'parameters': [{'name': 'session_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'uuid',
#         'title': 'Session Id'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/FilterViewCreate'}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/FilterView'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'get': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'get': {'summary': 'Read Filter View'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'get': {'description': 'Get a specific filter view.'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'get': {'operationId': 'read_filter_view_api_v1_sessions__session_id__views__view_id__get'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'get': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'get': {'parameters': [{'name': 'session_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Session Id'}},
#       {'name': 'view_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'uuid',
#         'title': 'View Id'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/FilterView'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'summary': 'Update Filter View'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'description': 'Update a filter view.'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'operationId': 'update_filter_view_api_v1_sessions__session_id__views__view_id__patch'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'parameters': [{'name': 'session_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Session Id'}},
#       {'name': 'view_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'uuid',
#         'title': 'View Id'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/FilterViewUpdate'}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/FilterView'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'delete': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'delete': {'summary': 'Delete Filter View'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'delete': {'description': 'Delete a specific filter view.'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'delete': {'operationId': 'delete_filter_view_api_v1_sessions__session_id__views__view_id__delete'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'delete': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'delete': {'parameters': [{'name': 'session_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Session Id'}},
#       {'name': 'view_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'uuid',
#         'title': 'View Id'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'delete': {'responses': {'200': {'description': 'Successful Response',
#        'content': {'application/json': {'schema': {}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'delete': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'delete': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'tags': ['orgs'],
#      'summary': 'List Organizations'}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'description': 'Get all orgs visible to this auth'}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'operationId': 'list_organizations_api_v1_orgs_get'}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'security': [{'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'parameters': [{'name': 'skip_create',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'boolean',
#         'default': False,
#         'title': 'Skip Create'}}]}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'type': 'array'}}}}}}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'items': {'$ref': '#/components/schemas/OrganizationPGSchemaSlim'}}}}}}}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'title': 'Response List Organizations Api V1 Orgs Get'}}}}}}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs': {'post': {'tags': ['orgs'],
#      'summary': 'Create Organization'}}}},
#  {'paths': {'/api/v1/orgs': {'post': {'operationId': 'create_organization_api_v1_orgs_post'}}}},
#  {'paths': {'/api/v1/orgs': {'post': {'security': [{'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/orgs': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/OrganizationCreate'}}}}}}}},
#  {'paths': {'/api/v1/orgs': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/OrganizationPGSchemaSlim'}}}}}}}}},
#  {'paths': {'/api/v1/orgs': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/setup': {'post': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/setup': {'post': {'summary': 'Create Customers And Get Stripe Setup Intent'}}}},
#  {'paths': {'/api/v1/orgs/current/setup': {'post': {'operationId': 'create_customers_and_get_stripe_setup_intent_api_v1_orgs_current_setup_post'}}}},
#  {'paths': {'/api/v1/orgs/current/setup': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/setup': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/StripeSetupIntentResponse'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/setup': {'post': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current': {'get': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current': {'get': {'summary': 'Get Organization Info'}}}},
#  {'paths': {'/api/v1/orgs/current': {'get': {'operationId': 'get_organization_info_api_v1_orgs_current_get'}}}},
#  {'paths': {'/api/v1/orgs/current': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Organization'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current': {'get': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'get': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'get': {'summary': 'Get Current Organization Info'}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'get': {'operationId': 'get_current_organization_info_api_v1_orgs_current_info_get'}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/OrganizationInfo'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'get': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'patch': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'patch': {'summary': 'Update Current Organization Info'}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'patch': {'operationId': 'update_current_organization_info_api_v1_orgs_current_info_patch'}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'patch': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/OrganizationUpdate'}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'patch': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'patch': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'patch': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/OrganizationInfo'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'patch': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'patch': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'patch': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/billing': {'get': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/billing': {'get': {'summary': 'Get Organization Billing Info'}}}},
#  {'paths': {'/api/v1/orgs/current/billing': {'get': {'operationId': 'get_organization_billing_info_api_v1_orgs_current_billing_get'}}}},
#  {'paths': {'/api/v1/orgs/current/billing': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/billing': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/OrganizationBillingInfo'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/billing': {'get': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'summary': 'Get Dashboard'}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'operationId': 'get_dashboard_api_v1_orgs_current_dashboard_get'}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'parameters': [{'name': 'type',
#        'in': 'query',
#        'required': True,
#        'schema': {'$ref': '#/components/schemas/OrganizationDashboardType'}},
#       {'name': 'color_scheme',
#        'in': 'query',
#        'required': True,
#        'schema': {'anyOf': [{'$ref': '#/components/schemas/OrganizationDashboardColorScheme'},
#          {'type': 'null'}],
#         'title': 'Color Scheme'}}]}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/OrganizationDashboardSchema'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'summary': 'On Payment Method Created'}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'operationId': 'on_payment_method_created_api_v1_orgs_current_payment_method_post'}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/StripePaymentInformation'}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'responses': {'200': {'description': 'Successful Response',
#        'content': {'application/json': {'schema': {}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'get': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'get': {'summary': 'Get Company Info'}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'get': {'operationId': 'get_company_info_api_v1_orgs_current_business_info_get'}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/StripeBusinessInfo-Output'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'get': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'post': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'post': {'summary': 'Set Company Info'}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'post': {'operationId': 'set_company_info_api_v1_orgs_current_business_info_post'}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/StripeBusinessInfo-Input'}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'post': {'responses': {'200': {'description': 'Successful Response',
#        'content': {'application/json': {'schema': {}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'post': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'summary': 'Change Payment Plan'}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'operationId': 'change_payment_plan_api_v1_orgs_current_plan_post'}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/ChangePaymentPlanSchema'}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'responses': {'200': {'description': 'Successful Response',
#        'content': {'application/json': {'schema': {}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'get': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'get': {'summary': 'List Organization Roles'}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'get': {'operationId': 'list_organization_roles_api_v1_orgs_current_roles_get'}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'items': {'$ref': '#/components/schemas/Role'}}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'type': 'array'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'title': 'Response List Organization Roles Api V1 Orgs Current Roles Get'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'get': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'post': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'post': {'summary': 'Create Organization Roles'}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'post': {'operationId': 'create_organization_roles_api_v1_orgs_current_roles_post'}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/CreateRoleRequest'}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Role'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'post': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'delete': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'delete': {'summary': 'Delete Organization Roles'}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'delete': {'operationId': 'delete_organization_roles_api_v1_orgs_current_roles__role_id__delete'}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'delete': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'delete': {'parameters': [{'name': 'role_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'uuid',
#         'title': 'Role Id'}}]}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'delete': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'delete': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Role'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'delete': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'delete': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'summary': 'Update Organization Roles'}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'operationId': 'update_organization_roles_api_v1_orgs_current_roles__role_id__patch'}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'parameters': [{'name': 'role_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'uuid',
#         'title': 'Role Id'}}]}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/UpdateRoleRequest'}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Role'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/permissions': {'get': {'tags': ['orgs'],
#      'summary': 'List Permissions'}}}},
#  {'paths': {'/api/v1/orgs/permissions': {'get': {'operationId': 'list_permissions_api_v1_orgs_permissions_get'}}}},
#  {'paths': {'/api/v1/orgs/permissions': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/permissions': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'items': {'$ref': '#/components/schemas/PermissionResponse'}}}}}}}}}},
#  {'paths': {'/api/v1/orgs/permissions': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'type': 'array'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/permissions': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'title': 'Response List Permissions Api V1 Orgs Permissions Get'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/permissions': {'get': {'security': [{'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/pending': {'get': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/pending': {'get': {'summary': 'List Pending Organization Invites'}}}},
#  {'paths': {'/api/v1/orgs/pending': {'get': {'description': 'Get all pending orgs visible to this auth'}}}},
#  {'paths': {'/api/v1/orgs/pending': {'get': {'operationId': 'list_pending_organization_invites_api_v1_orgs_pending_get'}}}},
#  {'paths': {'/api/v1/orgs/pending': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/pending': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'items': {'$ref': '#/components/schemas/OrganizationPGSchemaSlim'}}}}}}}}}},
#  {'paths': {'/api/v1/orgs/pending': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'type': 'array'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/pending': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'title': 'Response List Pending Organization Invites Api V1 Orgs Pending Get'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/pending': {'get': {'security': [{'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'get': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'get': {'summary': 'Get Current Org Members'}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'get': {'operationId': 'get_current_org_members_api_v1_orgs_current_members_get'}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/OrganizationMembers'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'get': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'post': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'post': {'summary': 'Add Member To Current Org'}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'post': {'operationId': 'add_member_to_current_org_api_v1_orgs_current_members_post'}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/PendingIdentityCreate'}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/PendingIdentity'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'post': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
# ...
#  {'paths': {'/api/v1/datasets/{dataset_id}/versions/diff': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/DatasetDiffInfo'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/versions/diff': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/versions/diff': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/version': {'get': {'tags': ['datasets']}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/version': {'get': {'summary': 'Get Dataset Version'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/version': {'get': {'description': 'Get dataset version by as_of or exact tag.'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/version': {'get': {'operationId': 'get_dataset_version_api_v1_datasets__dataset_id__version_get'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/version': {'get': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/version': {'get': {'parameters': [{'name': 'dataset_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Dataset Id'}},
#       {'name': 'as_of',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string', 'format': 'date-time'},
#          {'type': 'null'}],
#         'title': 'As Of'}},
#       {'name': 'tag',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'title': 'Tag'}}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/version': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/version': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/DatasetVersion'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/version': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/version': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'tags': ['datasets']}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'summary': 'Update Dataset Version'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'description': 'Set a tag on a dataset version.'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'operationId': 'update_dataset_version_api_v1_datasets__dataset_id__tags_put'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'parameters': [{'name': 'dataset_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'uuid',
#         'title': 'Dataset Id'}}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/PutDatasetVersionsSchema'}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/DatasetVersion'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai': {'get': {'tags': ['datasets']}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai': {'get': {'summary': 'Download Dataset Openai'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai': {'get': {'description': 'Download a dataset as OpenAI Evals Jsonl format.'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai': {'get': {'operationId': 'download_dataset_openai_api_v1_datasets__dataset_id__openai_get'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai': {'get': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai': {'get': {'parameters': [{'name': 'dataset_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Dataset Id'}},
#       {'name': 'as_of',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string', 'format': 'date-time'},
#          {'type': 'null'}],
#         'description': 'Only modifications made on or before this time are included. If None, the latest version of the dataset is used.',
#         'title': 'As Of'},
#        'description': 'Only modifications made on or before this time are included. If None, the latest version of the dataset is used.'}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai': {'get': {'responses': {'200': {'description': 'Successful Response',
#        'content': {'application/json': {'schema': {}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai_ft': {'get': {'tags': ['datasets']}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai_ft': {'get': {'summary': 'Download Dataset Openai Ft'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai_ft': {'get': {'description': 'Download a dataset as OpenAI Jsonl format.'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai_ft': {'get': {'operationId': 'download_dataset_openai_ft_api_v1_datasets__dataset_id__openai_ft_get'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai_ft': {'get': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai_ft': {'get': {'parameters': [{'name': 'dataset_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Dataset Id'}},
#       {'name': 'as_of',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string', 'format': 'date-time'},
#          {'type': 'null'}],
#         'description': 'Only modifications made on or before this time are included. If None, the latest version of the dataset is used.',
#         'title': 'As Of'},
#        'description': 'Only modifications made on or before this time are included. If None, the latest version of the dataset is used.'}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai_ft': {'get': {'responses': {'200': {'description': 'Successful Response',
#        'content': {'application/json': {'schema': {}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai_ft': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai_ft': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/csv': {'get': {'tags': ['datasets']}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/csv': {'get': {'summary': 'Download Dataset Csv'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/csv': {'get': {'description': 'Download a dataset as CSV format.'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/csv': {'get': {'operationId': 'download_dataset_csv_api_v1_datasets__dataset_id__csv_get'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/csv': {'get': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/csv': {'get': {'parameters': [{'name': 'dataset_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Dataset Id'}},
#       {'name': 'as_of',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string', 'format': 'date-time'},
#          {'type': 'null'}],
#         'description': 'Only modifications made on or before this time are included. If None, the latest version of the dataset is used.',
#         'title': 'As Of'},
#        'description': 'Only modifications made on or before this time are included. If None, the latest version of the dataset is used.'}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/csv': {'get': {'responses': {'200': {'description': 'Successful Response',
#        'content': {'application/json': {'schema': {}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/csv': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/csv': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/jsonl': {'get': {'tags': ['datasets']}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/jsonl': {'get': {'summary': 'Download Dataset Jsonl'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/jsonl': {'get': {'description': 'Download a dataset as CSV format.'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/jsonl': {'get': {'operationId': 'download_dataset_jsonl_api_v1_datasets__dataset_id__jsonl_get'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/jsonl': {'get': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/jsonl': {'get': {'parameters': [{'name': 'dataset_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Dataset Id'}},
#       {'name': 'as_of',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string', 'format': 'date-time'},
#          {'type': 'null'}],
#         'description': 'Only modifications made on or before this time are included. If None, the latest version of the dataset is used.',
#         'title': 'As Of'},
#        'description': 'Only modifications made on or before this time are included. If None, the latest version of the dataset is used.'}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/jsonl': {'get': {'responses': {'200': {'description': 'Successful Response',
#        'content': {'application/json': {'schema': {}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/jsonl': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/jsonl': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'tags': ['datasets']}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'summary': 'Read Examples With Runs'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'description': 'Fetch examples for a dataset, and fetch the runs for each example if they are associated with the given session_ids.'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'operationId': 'read_examples_with_runs_api_v1_datasets__dataset_id__runs_post'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'parameters': [{'name': 'dataset_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Dataset Id'}},
#       {'name': 'format',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'description': "Response format, e.g., 'csv'",
#         'title': 'Format'},
#        'description': "Response format, e.g., 'csv'"}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/QueryExampleSchemaWithRuns'}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'anyOf': [{'type': 'array',
#             'items': {'$ref': '#/components/schemas/ExampleWithRuns'}},
#            {'type': 'array',
#             'items': {'$ref': '#/components/schemas/ExampleWithRunsCH'}},
#            {'type': 'null'}]}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'title': 'Response Read Examples With Runs Api V1 Datasets  Dataset Id  Runs Post'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'tags': ['datasets']}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'summary': 'Read Examples With Runs Grouped'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'description': 'Fetch examples for a dataset, and fetch the runs for each example if they are associated with the given session_ids.'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'operationId': 'read_examples_with_runs_grouped_api_v1_datasets__dataset_id__group_runs_post'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'parameters': [{'name': 'dataset_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'uuid',
#         'title': 'Dataset Id'}}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/QueryGroupedExamplesWithRuns'}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/GroupedExamplesWithRunsResponse'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs/delta': {'post': {'tags': ['datasets']}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs/delta': {'post': {'summary': 'Read Delta'}}}},
#  ...]

# %%
for chunk in splitted_json[:3]:
    print(chunk)
# Out:
# {'openapi': '3.1.0', 'info': {'title': 'LangSmith', 'version': '0.1.0'}}
# {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'tags': ['tracer-sessions']}}}}
# {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'summary': 'Get Tracing Project Prebuilt Dashboard'}}}}

# %%
## Splitter can also output documents

docs = json_splitter.create_documents(texts=[json_data])

for doc in docs[:3]:
    print(doc)
# Out:
# page_content='{"openapi": "3.1.0", "info": {"title": "LangSmith", "version": "0.1.0"}}'
# page_content='{"paths": {"/api/v1/sessions/{session_id}/dashboard": {"post": {"tags": ["tracer-sessions"]}}}}'
# page_content='{"paths": {"/api/v1/sessions/{session_id}/dashboard": {"post": {"summary": "Get Tracing Project Prebuilt Dashboard"}}}}'

# %%
texts = json_splitter.split_text(json_data)
texts
# Out:
# ['{"openapi": "3.1.0", "info": {"title": "LangSmith", "version": "0.1.0"}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/dashboard": {"post": {"tags": ["tracer-sessions"]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/dashboard": {"post": {"summary": "Get Tracing Project Prebuilt Dashboard"}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/dashboard": {"post": {"description": "Get a prebuilt dashboard for a tracing project."}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/dashboard": {"post": {"operationId": "get_tracing_project_prebuilt_dashboard_api_v1_sessions__session_id__dashboard_post"}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/dashboard": {"post": {"security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/dashboard": {"post": {"parameters": [{"name": "session_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Session Id"}}, {"name": "accept", "in": "header", "required": false, "schema": {"anyOf": [{"type": "string"}, {"type": "null"}], "title": "Accept"}}]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/dashboard": {"post": {"requestBody": {"required": true}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/dashboard": {"post": {"requestBody": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/CustomChartsSectionRequest"}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/dashboard": {"post": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/dashboard": {"post": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/CustomChartsSection"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/dashboard": {"post": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/dashboard": {"post": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"get": {"tags": ["tracer-sessions"]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"get": {"summary": "Read Tracer Session"}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"get": {"description": "Get a specific session."}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"get": {"operationId": "read_tracer_session_api_v1_sessions__session_id__get"}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"get": {"security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"get": {"parameters": [{"name": "session_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Session Id"}}, {"name": "include_stats", "in": "query", "required": false, "schema": {"type": "boolean", "default": false, "title": "Include Stats"}}, {"name": "accept", "in": "header", "required": false, "schema": {"anyOf": [{"type": "string"}, {"type": "null"}], "title": "Accept"}}]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"get": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/TracerSession"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"get": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"get": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"patch": {"tags": ["tracer-sessions"]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"patch": {"summary": "Update Tracer Session"}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"patch": {"description": "Create a new session."}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"patch": {"operationId": "update_tracer_session_api_v1_sessions__session_id__patch"}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"patch": {"security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"patch": {"parameters": [{"name": "session_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Session Id"}}]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"patch": {"requestBody": {"required": true}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"patch": {"requestBody": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/TracerSessionUpdate"}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"patch": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"patch": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/TracerSessionWithoutVirtualFields"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"patch": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"patch": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"delete": {"tags": ["tracer-sessions"]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"delete": {"summary": "Delete Tracer Session"}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"delete": {"description": "Delete a specific session."}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"delete": {"operationId": "delete_tracer_session_api_v1_sessions__session_id__delete"}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"delete": {"security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"delete": {"parameters": [{"name": "session_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Session Id"}}]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"delete": {"responses": {"200": {"description": "Successful Response", "content": {"application/json": {"schema": {}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"delete": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}": {"delete": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions": {"get": {"tags": ["tracer-sessions"]}}}}',
#  '{"paths": {"/api/v1/sessions": {"get": {"summary": "Read Tracer Sessions"}}}}',
#  '{"paths": {"/api/v1/sessions": {"get": {"description": "Get all sessions."}}}}',
#  '{"paths": {"/api/v1/sessions": {"get": {"operationId": "read_tracer_sessions_api_v1_sessions_get"}}}}',
#  '{"paths": {"/api/v1/sessions": {"get": {"security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/sessions": {"get": {"parameters": [{"name": "reference_free", "in": "query", "required": false, "schema": {"anyOf": [{"type": "boolean"}, {"type": "null"}], "title": "Reference Free"}}, {"name": "reference_dataset", "in": "query", "required": false, "schema": {"anyOf": [{"type": "array", "items": {"type": "string", "format": "uuid"}}, {"type": "null"}], "title": "Reference Dataset"}}, {"name": "id", "in": "query", "required": false, "schema": {"anyOf": [{"type": "array", "items": {"type": "string", "format": "uuid"}}, {"type": "null"}], "title": "Id"}}, {"name": "name", "in": "query", "required": false, "schema": {"anyOf": [{"type": "string"}, {"type": "null"}], "title": "Name"}}, {"name": "name_contains", "in": "query", "required": false, "schema": {"anyOf": [{"type": "string"}, {"type": "null"}], "title": "Name Contains"}}, {"name": "dataset_version", "in": "query", "required": false, "schema": {"anyOf": [{"type": "string"}, {"type": "null"}], "title": "Dataset Version"}}, {"name": "sort_by", "in": "query", "required": false, "schema": {"$ref": "#/components/schemas/SessionSortableColumns", "default": "start_time"}}, {"name": "sort_by_desc", "in": "query", "required": false, "schema": {"type": "boolean", "default": true, "title": "Sort By Desc"}}, {"name": "metadata", "in": "query", "required": false, "schema": {"anyOf": [{"type": "string"}, {"type": "null"}], "title": "Metadata"}}, {"name": "sort_by_feedback_key", "in": "query", "required": false, "schema": {"anyOf": [{"type": "string"}, {"type": "null"}], "title": "Sort By Feedback Key"}}, {"name": "offset", "in": "query", "required": false, "schema": {"type": "integer", "minimum": 0, "default": 0, "title": "Offset"}}, {"name": "limit", "in": "query", "required": false, "schema": {"type": "integer", "maximum": 100, "minimum": 1, "default": 100, "title": "Limit"}}, {"name": "tag_value_id", "in": "query", "required": false, "schema": {"anyOf": [{"type": "array", "items": {"type": "string", "format": "uuid"}}, {"type": "null"}], "title": "Tag Value Id"}}, {"name": "facets", "in": "query", "required": false, "schema": {"type": "boolean", "default": false, "title": "Facets"}}, {"name": "filter", "in": "query", "required": false, "schema": {"anyOf": [{"type": "string"}, {"type": "null"}], "title": "Filter"}}, {"name": "include_stats", "in": "query", "required": false, "schema": {"type": "boolean", "default": false, "title": "Include Stats"}}, {"name": "use_approx_stats", "in": "query", "required": false, "schema": {"type": "boolean", "default": false, "title": "Use Approx Stats"}}, {"name": "accept", "in": "header", "required": false, "schema": {"anyOf": [{"type": "string"}, {"type": "null"}], "title": "Accept"}}]}}}}',
#  '{"paths": {"/api/v1/sessions": {"get": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/sessions": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"type": "array"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"items": {"$ref": "#/components/schemas/TracerSession"}}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"title": "Response Read Tracer Sessions Api V1 Sessions Get"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions": {"get": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/sessions": {"get": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions": {"post": {"tags": ["tracer-sessions"]}}}}',
#  '{"paths": {"/api/v1/sessions": {"post": {"summary": "Create Tracer Session"}}}}',
#  '{"paths": {"/api/v1/sessions": {"post": {"description": "Create a new session."}}}}',
#  '{"paths": {"/api/v1/sessions": {"post": {"operationId": "create_tracer_session_api_v1_sessions_post"}}}}',
#  '{"paths": {"/api/v1/sessions": {"post": {"security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/sessions": {"post": {"parameters": [{"name": "upsert", "in": "query", "required": false, "schema": {"type": "boolean", "default": false, "title": "Upsert"}}]}}}}',
#  '{"paths": {"/api/v1/sessions": {"post": {"requestBody": {"required": true}}}}}',
#  '{"paths": {"/api/v1/sessions": {"post": {"requestBody": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/TracerSessionCreate"}}}}}}}}',
#  '{"paths": {"/api/v1/sessions": {"post": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/sessions": {"post": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/TracerSessionWithoutVirtualFields"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions": {"post": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/sessions": {"post": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions": {"delete": {"tags": ["tracer-sessions"]}}}}',
#  '{"paths": {"/api/v1/sessions": {"delete": {"summary": "Delete Tracer Sessions"}}}}',
#  '{"paths": {"/api/v1/sessions": {"delete": {"description": "Delete a specific session."}}}}',
#  '{"paths": {"/api/v1/sessions": {"delete": {"operationId": "delete_tracer_sessions_api_v1_sessions_delete"}}}}',
#  '{"paths": {"/api/v1/sessions": {"delete": {"security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/sessions": {"delete": {"parameters": [{"name": "session_ids", "in": "query", "required": true, "schema": {"type": "array", "items": {"type": "string", "format": "uuid"}, "title": "Session Ids"}}]}}}}',
#  '{"paths": {"/api/v1/sessions": {"delete": {"responses": {"200": {"description": "Successful Response", "content": {"application/json": {"schema": {}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions": {"delete": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/sessions": {"delete": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/metadata": {"get": {"tags": ["tracer-sessions"]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/metadata": {"get": {"summary": "Read Tracer Sessions Runs Metadata"}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/metadata": {"get": {"description": "Given a session, a number K, and (optionally) a list of metadata keys, return the top K values for each key."}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/metadata": {"get": {"operationId": "read_tracer_sessions_runs_metadata_api_v1_sessions__session_id__metadata_get"}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/metadata": {"get": {"security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/metadata": {"get": {"parameters": [{"name": "session_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Session Id"}}, {"name": "metadata_keys", "in": "query", "required": false, "schema": {"anyOf": [{"type": "array", "items": {"type": "string"}}, {"type": "null"}], "title": "Metadata Keys"}}, {"name": "start_time", "in": "query", "required": false, "schema": {"anyOf": [{"type": "string", "format": "date-time"}, {"type": "null"}], "title": "Start Time"}}, {"name": "k", "in": "query", "required": false, "schema": {"type": "integer", "minimum": 1, "default": 10, "title": "K"}}, {"name": "root_runs_only", "in": "query", "required": false, "schema": {"type": "boolean", "default": false, "title": "Root Runs Only"}}]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/metadata": {"get": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/metadata": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/RootModel_Dict_str__list_str___"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/metadata": {"get": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/metadata": {"get": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"get": {"tags": ["tracer-sessions"]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"get": {"summary": "Read Filter Views"}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"get": {"description": "Get all filter views for a session."}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"get": {"operationId": "read_filter_views_api_v1_sessions__session_id__views_get"}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"get": {"security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"get": {"parameters": [{"name": "session_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Session Id"}}, {"name": "type", "in": "query", "required": false, "schema": {"anyOf": [{"$ref": "#/components/schemas/FilterViewType"}, {"type": "null"}], "title": "Type"}}]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"get": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"type": "array"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"items": {"$ref": "#/components/schemas/FilterView"}}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"title": "Response Read Filter Views Api V1 Sessions  Session Id  Views Get"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"get": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"get": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"post": {"tags": ["tracer-sessions"]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"post": {"summary": "Create Filter View"}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"post": {"description": "Create a new filter view."}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"post": {"operationId": "create_filter_view_api_v1_sessions__session_id__views_post"}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"post": {"security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"post": {"parameters": [{"name": "session_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Session Id"}}]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"post": {"requestBody": {"required": true}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"post": {"requestBody": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/FilterViewCreate"}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"post": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"post": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/FilterView"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"post": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views": {"post": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"get": {"tags": ["tracer-sessions"]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"get": {"summary": "Read Filter View"}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"get": {"description": "Get a specific filter view."}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"get": {"operationId": "read_filter_view_api_v1_sessions__session_id__views__view_id__get"}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"get": {"security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"get": {"parameters": [{"name": "session_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Session Id"}}, {"name": "view_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "View Id"}}]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"get": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/FilterView"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"get": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"get": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"patch": {"tags": ["tracer-sessions"]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"patch": {"summary": "Update Filter View"}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"patch": {"description": "Update a filter view."}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"patch": {"operationId": "update_filter_view_api_v1_sessions__session_id__views__view_id__patch"}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"patch": {"security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"patch": {"parameters": [{"name": "session_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Session Id"}}, {"name": "view_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "View Id"}}]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"patch": {"requestBody": {"required": true}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"patch": {"requestBody": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/FilterViewUpdate"}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"patch": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"patch": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/FilterView"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"patch": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"patch": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"delete": {"tags": ["tracer-sessions"]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"delete": {"summary": "Delete Filter View"}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"delete": {"description": "Delete a specific filter view."}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"delete": {"operationId": "delete_filter_view_api_v1_sessions__session_id__views__view_id__delete"}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"delete": {"security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"delete": {"parameters": [{"name": "session_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Session Id"}}, {"name": "view_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "View Id"}}]}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"delete": {"responses": {"200": {"description": "Successful Response", "content": {"application/json": {"schema": {}}}}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"delete": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/sessions/{session_id}/views/{view_id}": {"delete": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs": {"get": {"tags": ["orgs"], "summary": "List Organizations"}}}}',
#  '{"paths": {"/api/v1/orgs": {"get": {"description": "Get all orgs visible to this auth"}}}}',
#  '{"paths": {"/api/v1/orgs": {"get": {"operationId": "list_organizations_api_v1_orgs_get"}}}}',
#  '{"paths": {"/api/v1/orgs": {"get": {"security": [{"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/orgs": {"get": {"parameters": [{"name": "skip_create", "in": "query", "required": false, "schema": {"type": "boolean", "default": false, "title": "Skip Create"}}]}}}}',
#  '{"paths": {"/api/v1/orgs": {"get": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/orgs": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"type": "array"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"items": {"$ref": "#/components/schemas/OrganizationPGSchemaSlim"}}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"title": "Response List Organizations Api V1 Orgs Get"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs": {"get": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/orgs": {"get": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs": {"post": {"tags": ["orgs"], "summary": "Create Organization"}}}}',
#  '{"paths": {"/api/v1/orgs": {"post": {"operationId": "create_organization_api_v1_orgs_post"}}}}',
#  '{"paths": {"/api/v1/orgs": {"post": {"security": [{"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/orgs": {"post": {"requestBody": {"required": true}}}}}',
#  '{"paths": {"/api/v1/orgs": {"post": {"requestBody": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/OrganizationCreate"}}}}}}}}',
#  '{"paths": {"/api/v1/orgs": {"post": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/orgs": {"post": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/OrganizationPGSchemaSlim"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs": {"post": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/orgs": {"post": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/setup": {"post": {"tags": ["orgs"]}}}}',
#  '{"paths": {"/api/v1/orgs/current/setup": {"post": {"summary": "Create Customers And Get Stripe Setup Intent"}}}}',
#  '{"paths": {"/api/v1/orgs/current/setup": {"post": {"operationId": "create_customers_and_get_stripe_setup_intent_api_v1_orgs_current_setup_post"}}}}',
#  '{"paths": {"/api/v1/orgs/current/setup": {"post": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/setup": {"post": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/StripeSetupIntentResponse"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/setup": {"post": {"security": [{"API Key": []}, {"Organization ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/orgs/current": {"get": {"tags": ["orgs"]}}}}',
#  '{"paths": {"/api/v1/orgs/current": {"get": {"summary": "Get Organization Info"}}}}',
#  '{"paths": {"/api/v1/orgs/current": {"get": {"operationId": "get_organization_info_api_v1_orgs_current_get"}}}}',
#  '{"paths": {"/api/v1/orgs/current": {"get": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/Organization"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current": {"get": {"security": [{"API Key": []}, {"Organization ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/orgs/current/info": {"get": {"tags": ["orgs"]}}}}',
#  '{"paths": {"/api/v1/orgs/current/info": {"get": {"summary": "Get Current Organization Info"}}}}',
#  '{"paths": {"/api/v1/orgs/current/info": {"get": {"operationId": "get_current_organization_info_api_v1_orgs_current_info_get"}}}}',
#  '{"paths": {"/api/v1/orgs/current/info": {"get": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/info": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/OrganizationInfo"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/info": {"get": {"security": [{"API Key": []}, {"Organization ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/orgs/current/info": {"patch": {"tags": ["orgs"]}}}}',
#  '{"paths": {"/api/v1/orgs/current/info": {"patch": {"summary": "Update Current Organization Info"}}}}',
#  '{"paths": {"/api/v1/orgs/current/info": {"patch": {"operationId": "update_current_organization_info_api_v1_orgs_current_info_patch"}}}}',
#  '{"paths": {"/api/v1/orgs/current/info": {"patch": {"requestBody": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/OrganizationUpdate"}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/info": {"patch": {"requestBody": {"required": true}}}}}',
#  '{"paths": {"/api/v1/orgs/current/info": {"patch": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/info": {"patch": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/OrganizationInfo"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/info": {"patch": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/info": {"patch": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/info": {"patch": {"security": [{"API Key": []}, {"Organization ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/orgs/current/billing": {"get": {"tags": ["orgs"]}}}}',
#  '{"paths": {"/api/v1/orgs/current/billing": {"get": {"summary": "Get Organization Billing Info"}}}}',
#  '{"paths": {"/api/v1/orgs/current/billing": {"get": {"operationId": "get_organization_billing_info_api_v1_orgs_current_billing_get"}}}}',
#  '{"paths": {"/api/v1/orgs/current/billing": {"get": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/billing": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/OrganizationBillingInfo"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/billing": {"get": {"security": [{"API Key": []}, {"Organization ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/orgs/current/dashboard": {"get": {"tags": ["orgs"]}}}}',
#  '{"paths": {"/api/v1/orgs/current/dashboard": {"get": {"summary": "Get Dashboard"}}}}',
#  '{"paths": {"/api/v1/orgs/current/dashboard": {"get": {"operationId": "get_dashboard_api_v1_orgs_current_dashboard_get"}}}}',
#  '{"paths": {"/api/v1/orgs/current/dashboard": {"get": {"security": [{"API Key": []}, {"Organization ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/orgs/current/dashboard": {"get": {"parameters": [{"name": "type", "in": "query", "required": true, "schema": {"$ref": "#/components/schemas/OrganizationDashboardType"}}, {"name": "color_scheme", "in": "query", "required": true, "schema": {"anyOf": [{"$ref": "#/components/schemas/OrganizationDashboardColorScheme"}, {"type": "null"}], "title": "Color Scheme"}}]}}}}',
#  '{"paths": {"/api/v1/orgs/current/dashboard": {"get": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/dashboard": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/OrganizationDashboardSchema"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/dashboard": {"get": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/dashboard": {"get": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/payment-method": {"post": {"tags": ["orgs"]}}}}',
#  '{"paths": {"/api/v1/orgs/current/payment-method": {"post": {"summary": "On Payment Method Created"}}}}',
#  '{"paths": {"/api/v1/orgs/current/payment-method": {"post": {"operationId": "on_payment_method_created_api_v1_orgs_current_payment_method_post"}}}}',
#  '{"paths": {"/api/v1/orgs/current/payment-method": {"post": {"requestBody": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/StripePaymentInformation"}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/payment-method": {"post": {"requestBody": {"required": true}}}}}',
#  '{"paths": {"/api/v1/orgs/current/payment-method": {"post": {"responses": {"200": {"description": "Successful Response", "content": {"application/json": {"schema": {}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/payment-method": {"post": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/payment-method": {"post": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/payment-method": {"post": {"security": [{"API Key": []}, {"Organization ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/orgs/current/business-info": {"get": {"tags": ["orgs"]}}}}',
#  '{"paths": {"/api/v1/orgs/current/business-info": {"get": {"summary": "Get Company Info"}}}}',
#  '{"paths": {"/api/v1/orgs/current/business-info": {"get": {"operationId": "get_company_info_api_v1_orgs_current_business_info_get"}}}}',
#  '{"paths": {"/api/v1/orgs/current/business-info": {"get": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/business-info": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/StripeBusinessInfo-Output"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/business-info": {"get": {"security": [{"API Key": []}, {"Organization ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/orgs/current/business-info": {"post": {"tags": ["orgs"]}}}}',
#  '{"paths": {"/api/v1/orgs/current/business-info": {"post": {"summary": "Set Company Info"}}}}',
#  '{"paths": {"/api/v1/orgs/current/business-info": {"post": {"operationId": "set_company_info_api_v1_orgs_current_business_info_post"}}}}',
#  '{"paths": {"/api/v1/orgs/current/business-info": {"post": {"requestBody": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/StripeBusinessInfo-Input"}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/business-info": {"post": {"requestBody": {"required": true}}}}}',
#  '{"paths": {"/api/v1/orgs/current/business-info": {"post": {"responses": {"200": {"description": "Successful Response", "content": {"application/json": {"schema": {}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/business-info": {"post": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/business-info": {"post": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/business-info": {"post": {"security": [{"API Key": []}, {"Organization ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/orgs/current/plan": {"post": {"tags": ["orgs"]}}}}',
#  '{"paths": {"/api/v1/orgs/current/plan": {"post": {"summary": "Change Payment Plan"}}}}',
#  '{"paths": {"/api/v1/orgs/current/plan": {"post": {"operationId": "change_payment_plan_api_v1_orgs_current_plan_post"}}}}',
#  '{"paths": {"/api/v1/orgs/current/plan": {"post": {"requestBody": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/ChangePaymentPlanSchema"}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/plan": {"post": {"requestBody": {"required": true}}}}}',
#  '{"paths": {"/api/v1/orgs/current/plan": {"post": {"responses": {"200": {"description": "Successful Response", "content": {"application/json": {"schema": {}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/plan": {"post": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/plan": {"post": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/plan": {"post": {"security": [{"API Key": []}, {"Organization ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles": {"get": {"tags": ["orgs"]}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles": {"get": {"summary": "List Organization Roles"}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles": {"get": {"operationId": "list_organization_roles_api_v1_orgs_current_roles_get"}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles": {"get": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"items": {"$ref": "#/components/schemas/Role"}}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"type": "array"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"title": "Response List Organization Roles Api V1 Orgs Current Roles Get"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles": {"get": {"security": [{"API Key": []}, {"Organization ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles": {"post": {"tags": ["orgs"]}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles": {"post": {"summary": "Create Organization Roles"}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles": {"post": {"operationId": "create_organization_roles_api_v1_orgs_current_roles_post"}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles": {"post": {"requestBody": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/CreateRoleRequest"}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles": {"post": {"requestBody": {"required": true}}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles": {"post": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles": {"post": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/Role"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles": {"post": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles": {"post": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles": {"post": {"security": [{"API Key": []}, {"Organization ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles/{role_id}": {"delete": {"tags": ["orgs"]}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles/{role_id}": {"delete": {"summary": "Delete Organization Roles"}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles/{role_id}": {"delete": {"operationId": "delete_organization_roles_api_v1_orgs_current_roles__role_id__delete"}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles/{role_id}": {"delete": {"security": [{"API Key": []}, {"Organization ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles/{role_id}": {"delete": {"parameters": [{"name": "role_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Role Id"}}]}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles/{role_id}": {"delete": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles/{role_id}": {"delete": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/Role"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles/{role_id}": {"delete": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles/{role_id}": {"delete": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles/{role_id}": {"patch": {"tags": ["orgs"]}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles/{role_id}": {"patch": {"summary": "Update Organization Roles"}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles/{role_id}": {"patch": {"operationId": "update_organization_roles_api_v1_orgs_current_roles__role_id__patch"}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles/{role_id}": {"patch": {"security": [{"API Key": []}, {"Organization ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles/{role_id}": {"patch": {"parameters": [{"name": "role_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Role Id"}}]}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles/{role_id}": {"patch": {"requestBody": {"required": true}}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles/{role_id}": {"patch": {"requestBody": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/UpdateRoleRequest"}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles/{role_id}": {"patch": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles/{role_id}": {"patch": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/Role"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles/{role_id}": {"patch": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/roles/{role_id}": {"patch": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/permissions": {"get": {"tags": ["orgs"], "summary": "List Permissions"}}}}',
#  '{"paths": {"/api/v1/orgs/permissions": {"get": {"operationId": "list_permissions_api_v1_orgs_permissions_get"}}}}',
#  '{"paths": {"/api/v1/orgs/permissions": {"get": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/orgs/permissions": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"items": {"$ref": "#/components/schemas/PermissionResponse"}}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/permissions": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"type": "array"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/permissions": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"title": "Response List Permissions Api V1 Orgs Permissions Get"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/permissions": {"get": {"security": [{"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/orgs/pending": {"get": {"tags": ["orgs"]}}}}',
#  '{"paths": {"/api/v1/orgs/pending": {"get": {"summary": "List Pending Organization Invites"}}}}',
#  '{"paths": {"/api/v1/orgs/pending": {"get": {"description": "Get all pending orgs visible to this auth"}}}}',
#  '{"paths": {"/api/v1/orgs/pending": {"get": {"operationId": "list_pending_organization_invites_api_v1_orgs_pending_get"}}}}',
#  '{"paths": {"/api/v1/orgs/pending": {"get": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/orgs/pending": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"items": {"$ref": "#/components/schemas/OrganizationPGSchemaSlim"}}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/pending": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"type": "array"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/pending": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"title": "Response List Pending Organization Invites Api V1 Orgs Pending Get"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/pending": {"get": {"security": [{"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/orgs/current/members": {"get": {"tags": ["orgs"]}}}}',
#  '{"paths": {"/api/v1/orgs/current/members": {"get": {"summary": "Get Current Org Members"}}}}',
#  '{"paths": {"/api/v1/orgs/current/members": {"get": {"operationId": "get_current_org_members_api_v1_orgs_current_members_get"}}}}',
#  '{"paths": {"/api/v1/orgs/current/members": {"get": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/members": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/OrganizationMembers"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/members": {"get": {"security": [{"API Key": []}, {"Organization ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/orgs/current/members": {"post": {"tags": ["orgs"]}}}}',
#  '{"paths": {"/api/v1/orgs/current/members": {"post": {"summary": "Add Member To Current Org"}}}}',
#  '{"paths": {"/api/v1/orgs/current/members": {"post": {"operationId": "add_member_to_current_org_api_v1_orgs_current_members_post"}}}}',
#  '{"paths": {"/api/v1/orgs/current/members": {"post": {"requestBody": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/PendingIdentityCreate"}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/members": {"post": {"requestBody": {"required": true}}}}}',
#  '{"paths": {"/api/v1/orgs/current/members": {"post": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/members": {"post": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/PendingIdentity"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/members": {"post": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/members": {"post": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/orgs/current/members": {"post": {"security": [{"API Key": []}, {"Organization ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/orgs/current/members/active": {"get": {"tags": ["orgs"]}}}}',
#  '{"paths": {"/api/v1/orgs/current/members/active": {"get": {"summary": "Get Current Active Org Members"}}}}',
#  '{"paths": {"/api/v1/orgs/current/members/active": {"get": {"operationId": "get_current_active_org_members_api_v1_orgs_current_members_active_get"}}}}',
#  '{"paths": {"/api/v1/orgs/current/members/active": {"get": {"security": [{"API Key": []}, {"Organization ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/orgs/current/members/active": {"get": {"parameters": [{"name": "limit", "in": "query", "required": false, "schema": {"type": "integer", "maximum": 500, "minimum": 1, "default": 50, "title": "Limit"}}, {"name": "offset", "in": "query", "required": false, "schema": {"type": "integer", "minimum": 0, "default": 0, "title": "Offset"}}, {"name": "emails", "in": "query", "required": false, "schema": {"type": "array", "items": {"type": "string"}, "default": [], "title": "Emails"}}, {"name": "ls_user_ids", "in": "query", "required": false, "schema": {"type": "array", "items": {"type": "string", "format": "uuid"}, "default": [], "title": "Ls User Ids"}}, {"name": "user_ids", "in": "query", "required": false, "schema": {"type": "array", "items": {"type": "string", "format": "uuid"}, "default": [], "title": "User Ids"}}]}}}}',
#  '{"paths": {"/api/v1/orgs/current/members/active": {"get": {"responses": {"200": {"description": "Successful Response"}}}}}}',
# ...
#  '{"paths": {"/api/v1/datasets/{dataset_id}/versions/diff": {"get": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/versions/diff": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/DatasetDiffInfo"}}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/versions/diff": {"get": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/versions/diff": {"get": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/version": {"get": {"tags": ["datasets"]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/version": {"get": {"summary": "Get Dataset Version"}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/version": {"get": {"description": "Get dataset version by as_of or exact tag."}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/version": {"get": {"operationId": "get_dataset_version_api_v1_datasets__dataset_id__version_get"}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/version": {"get": {"security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/version": {"get": {"parameters": [{"name": "dataset_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Dataset Id"}}, {"name": "as_of", "in": "query", "required": false, "schema": {"anyOf": [{"type": "string", "format": "date-time"}, {"type": "null"}], "title": "As Of"}}, {"name": "tag", "in": "query", "required": false, "schema": {"anyOf": [{"type": "string"}, {"type": "null"}], "title": "Tag"}}]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/version": {"get": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/version": {"get": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/DatasetVersion"}}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/version": {"get": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/version": {"get": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/tags": {"put": {"tags": ["datasets"]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/tags": {"put": {"summary": "Update Dataset Version"}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/tags": {"put": {"description": "Set a tag on a dataset version."}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/tags": {"put": {"operationId": "update_dataset_version_api_v1_datasets__dataset_id__tags_put"}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/tags": {"put": {"security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/tags": {"put": {"parameters": [{"name": "dataset_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Dataset Id"}}]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/tags": {"put": {"requestBody": {"required": true}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/tags": {"put": {"requestBody": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/PutDatasetVersionsSchema"}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/tags": {"put": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/tags": {"put": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/DatasetVersion"}}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/tags": {"put": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/tags": {"put": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/openai": {"get": {"tags": ["datasets"]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/openai": {"get": {"summary": "Download Dataset Openai"}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/openai": {"get": {"description": "Download a dataset as OpenAI Evals Jsonl format."}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/openai": {"get": {"operationId": "download_dataset_openai_api_v1_datasets__dataset_id__openai_get"}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/openai": {"get": {"security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/openai": {"get": {"parameters": [{"name": "dataset_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Dataset Id"}}, {"name": "as_of", "in": "query", "required": false, "schema": {"anyOf": [{"type": "string", "format": "date-time"}, {"type": "null"}], "description": "Only modifications made on or before this time are included. If None, the latest version of the dataset is used.", "title": "As Of"}, "description": "Only modifications made on or before this time are included. If None, the latest version of the dataset is used."}]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/openai": {"get": {"responses": {"200": {"description": "Successful Response", "content": {"application/json": {"schema": {}}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/openai": {"get": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/openai": {"get": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/openai_ft": {"get": {"tags": ["datasets"]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/openai_ft": {"get": {"summary": "Download Dataset Openai Ft"}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/openai_ft": {"get": {"description": "Download a dataset as OpenAI Jsonl format."}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/openai_ft": {"get": {"operationId": "download_dataset_openai_ft_api_v1_datasets__dataset_id__openai_ft_get"}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/openai_ft": {"get": {"security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/openai_ft": {"get": {"parameters": [{"name": "dataset_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Dataset Id"}}, {"name": "as_of", "in": "query", "required": false, "schema": {"anyOf": [{"type": "string", "format": "date-time"}, {"type": "null"}], "description": "Only modifications made on or before this time are included. If None, the latest version of the dataset is used.", "title": "As Of"}, "description": "Only modifications made on or before this time are included. If None, the latest version of the dataset is used."}]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/openai_ft": {"get": {"responses": {"200": {"description": "Successful Response", "content": {"application/json": {"schema": {}}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/openai_ft": {"get": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/openai_ft": {"get": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/csv": {"get": {"tags": ["datasets"]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/csv": {"get": {"summary": "Download Dataset Csv"}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/csv": {"get": {"description": "Download a dataset as CSV format."}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/csv": {"get": {"operationId": "download_dataset_csv_api_v1_datasets__dataset_id__csv_get"}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/csv": {"get": {"security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/csv": {"get": {"parameters": [{"name": "dataset_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Dataset Id"}}, {"name": "as_of", "in": "query", "required": false, "schema": {"anyOf": [{"type": "string", "format": "date-time"}, {"type": "null"}], "description": "Only modifications made on or before this time are included. If None, the latest version of the dataset is used.", "title": "As Of"}, "description": "Only modifications made on or before this time are included. If None, the latest version of the dataset is used."}]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/csv": {"get": {"responses": {"200": {"description": "Successful Response", "content": {"application/json": {"schema": {}}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/csv": {"get": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/csv": {"get": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/jsonl": {"get": {"tags": ["datasets"]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/jsonl": {"get": {"summary": "Download Dataset Jsonl"}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/jsonl": {"get": {"description": "Download a dataset as CSV format."}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/jsonl": {"get": {"operationId": "download_dataset_jsonl_api_v1_datasets__dataset_id__jsonl_get"}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/jsonl": {"get": {"security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/jsonl": {"get": {"parameters": [{"name": "dataset_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Dataset Id"}}, {"name": "as_of", "in": "query", "required": false, "schema": {"anyOf": [{"type": "string", "format": "date-time"}, {"type": "null"}], "description": "Only modifications made on or before this time are included. If None, the latest version of the dataset is used.", "title": "As Of"}, "description": "Only modifications made on or before this time are included. If None, the latest version of the dataset is used."}]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/jsonl": {"get": {"responses": {"200": {"description": "Successful Response", "content": {"application/json": {"schema": {}}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/jsonl": {"get": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/jsonl": {"get": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/runs": {"post": {"tags": ["datasets"]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/runs": {"post": {"summary": "Read Examples With Runs"}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/runs": {"post": {"description": "Fetch examples for a dataset, and fetch the runs for each example if they are associated with the given session_ids."}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/runs": {"post": {"operationId": "read_examples_with_runs_api_v1_datasets__dataset_id__runs_post"}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/runs": {"post": {"security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/runs": {"post": {"parameters": [{"name": "dataset_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Dataset Id"}}, {"name": "format", "in": "query", "required": false, "schema": {"anyOf": [{"type": "string"}, {"type": "null"}], "description": "Response format, e.g., \'csv\'", "title": "Format"}, "description": "Response format, e.g., \'csv\'"}]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/runs": {"post": {"requestBody": {"required": true}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/runs": {"post": {"requestBody": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/QueryExampleSchemaWithRuns"}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/runs": {"post": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/runs": {"post": {"responses": {"200": {"content": {"application/json": {"schema": {"anyOf": [{"type": "array", "items": {"$ref": "#/components/schemas/ExampleWithRuns"}}, {"type": "array", "items": {"$ref": "#/components/schemas/ExampleWithRunsCH"}}, {"type": "null"}]}}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/runs": {"post": {"responses": {"200": {"content": {"application/json": {"schema": {"title": "Response Read Examples With Runs Api V1 Datasets  Dataset Id  Runs Post"}}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/runs": {"post": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/runs": {"post": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/group/runs": {"post": {"tags": ["datasets"]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/group/runs": {"post": {"summary": "Read Examples With Runs Grouped"}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/group/runs": {"post": {"description": "Fetch examples for a dataset, and fetch the runs for each example if they are associated with the given session_ids."}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/group/runs": {"post": {"operationId": "read_examples_with_runs_grouped_api_v1_datasets__dataset_id__group_runs_post"}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/group/runs": {"post": {"security": [{"API Key": []}, {"Tenant ID": []}, {"Bearer Auth": []}]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/group/runs": {"post": {"parameters": [{"name": "dataset_id", "in": "path", "required": true, "schema": {"type": "string", "format": "uuid", "title": "Dataset Id"}}]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/group/runs": {"post": {"requestBody": {"required": true}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/group/runs": {"post": {"requestBody": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/QueryGroupedExamplesWithRuns"}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/group/runs": {"post": {"responses": {"200": {"description": "Successful Response"}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/group/runs": {"post": {"responses": {"200": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/GroupedExamplesWithRunsResponse"}}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/group/runs": {"post": {"responses": {"422": {"description": "Validation Error"}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/group/runs": {"post": {"responses": {"422": {"content": {"application/json": {"schema": {"$ref": "#/components/schemas/HTTPValidationError"}}}}}}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/runs/delta": {"post": {"tags": ["datasets"]}}}}',
#  '{"paths": {"/api/v1/datasets/{dataset_id}/runs/delta": {"post": {"summary": "Read Delta"}}}}',
#  ...]
